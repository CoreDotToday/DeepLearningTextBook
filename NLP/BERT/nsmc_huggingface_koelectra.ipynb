# %% [markdown]
# # Pytorch + HuggingFace
# ## KoElectra Model
# 박장원님의 KoElectra-small 사용<br>
# https://monologg.kr/2020/05/02/koelectra-part1/<br>
# https://github.com/monologg/KoELECTRA
#
# ## Dataset
# 네이버 영화 리뷰 데이터셋<br>
# https://github.com/e9t/nsmc
#
# ## References
# - https://huggingface.co/transformers/training.html
# - https://tutorials.pytorch.kr/beginner/data_loading_tutorial.html
# - https://tutorials.pytorch.kr/beginner/blitz/cifar10_tutorial.html
# - https://wikidocs.net/44249
#
# ## 주의사항
# 꼭 GPU로 해주세요 - 1epoch 당 약 20분 소요

# %%
# HuggingFace transformers 설치 및 NSMC 데이터셋 다운로드
# !pip install transformers
# !wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# !wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Out:
# Collecting transformers
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 57.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.2 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.2
# --2023-09-23 14:27:06--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4893335 (4.7M) [text/plain]
# Saving to: ‘ratings_test.txt’
#
# ratings_test.txt    100%[===================>]   4.67M  --.-KB/s    in 0.03s
#
# 2023-09-23 14:27:07 (180 MB/s) - ‘ratings_test.txt’ saved [4893335/4893335]
#
# --2023-09-23 14:27:07--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14628807 (14M) [text/plain]
# Saving to: ‘ratings_train.txt’
#
# ratings_train.txt   100%[===================>]  13.95M  --.-KB/s    in 0.06s
#
# 2023-09-23 14:27:15 (246 MB/s) - ‘ratings_train.txt’ saved [14628807/14628807]

# %%
# !head ratings_train.txt
# !head ratings_test.txt
# Out:
# id	document	label
# 9976970	아 더빙.. 진짜 짜증나네요 목소리	0
# 3819312	흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나	1
# 10265843	너무재밓었다그래서보는것을추천한다	0
# 9045019	교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정	0
# 6483659	사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다	1
# 5403919	막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.	0
# 7797314	원작의 긴장감을 제대로 살려내지못했다.	0
# 9443947	별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네	0
# 7156791	액션이 없는데도 재미 있는 몇안되는 영화	1
# id	document	label
# 6270596	굳 ㅋ	1
# 9274899	GDNTOPCLASSINTHECLUB	0
# 8544678	뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아	0
# 6825595	지루하지는 않은데 완전 막장임... 돈주고 보기에는....	0
# 6723715	3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??	0
# 7898805	음악이 주가 된, 최고의 음악영화	1
# 6315043	진정한 쓰레기	0
# 6097171	마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다	0
# 8932678	갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다	0

# %%
import pandas as pd
import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, ElectraForSequenceClassification, AdamW
from tqdm.notebook import tqdm

# %%
# GPU 사용
device = torch.device("cuda")

# %% [markdown]
# # Dataset 만들어서 불러오기

# %%
class NSMCDataset(Dataset):

  def __init__(self, csv_file):
    # 일부 값중에 NaN이 있음...
    self.dataset = pd.read_csv(csv_file, sep='\t').dropna(axis=0)
    # 중복제거
    self.dataset.drop_duplicates(subset=['document'], inplace=True)
    self.tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-small-v2-discriminator")

    print(self.dataset.describe())

  def __len__(self):
    return len(self.dataset)

  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 1:3].values
    text = row[0]
    y = row[1]

    inputs = self.tokenizer(
        text,
        return_tensors='pt',
        truncation=True,
        max_length=256,
        pad_to_max_length=True,
        add_special_tokens=True
        )

    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask, y

# %%
train_dataset = NSMCDataset("ratings_train.txt")
test_dataset = NSMCDataset("ratings_test.txt")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/486 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/255k [00:00<?, ?B/s]
#                  id          label
# count  1.461820e+05  146182.000000
# mean   6.779186e+06       0.498283
# std    2.919223e+06       0.499999
# min    3.300000e+01       0.000000
# 25%    4.814832e+06       0.000000
# 50%    7.581160e+06       0.000000
# 75%    9.274760e+06       1.000000
# max    1.027815e+07       1.000000
#                  id         label
# count  4.915700e+04  49157.000000
# mean   6.752945e+06      0.502695
# std    2.937158e+06      0.499998
# min    6.010000e+02      0.000000
# 25%    4.777143e+06      0.000000
# 50%    7.565415e+06      1.000000
# 75%    9.260204e+06      1.000000
# max    1.027809e+07      1.000000

# %% [markdown]
# # Create Model

# %%
model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator").to(device)

# 한번 실행해보기
# text, attention_mask, y = train_dataset[0]
# model(text.unsqueeze(0).to(device), attention_mask=attention_mask.unsqueeze(0).to(device))
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/452M [00:00<?, ?B/s]
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.load_state_dict(torch.load("model.pt"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-92bba1eb9395> in <cell line: 1>()
# ----> 1 model.load_state_dict(torch.load("model.pt"))
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     789         pickle_load_args['encoding'] = 'utf-8'
#     790
# --> 791     with _open_file_like(f, 'rb') as opened_file:
#     792         if _is_zipfile(opened_file):
#     793             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     250 class _open_file(_opener):
#     251     def __init__(self, name, mode):
# --> 252         super().__init__(open(name, mode))
#     253
#     254     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.pt'

# %%
# 모델 레이어 보기
model
# Out:
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(35000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# # Learn

# %%
epochs = 5
batch_size = 16

# %%
optimizer = AdamW(model.parameters(), lr=5e-6)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
losses = []
accuracies = []

for i in range(epochs):
  total_loss = 0.0
  correct = 0
  total = 0
  batches = 0

  model.train()

  for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
    optimizer.zero_grad()
    y_batch = y_batch.to(device)
    y_pred = model(input_ids_batch.to(device),
                   attention_mask=attention_masks_batch.to(device))[0]
    loss = F.cross_entropy(y_pred, y_batch)
    loss.backward()
    optimizer.step()

    total_loss += loss.item()

    _, predicted = torch.max(y_pred, 1)
    correct += (predicted == y_batch).sum()
    total += len(y_batch)

    batches += 1
    if batches % 100 == 0:
      print("Batch Loss:", total_loss, "Accuracy:", correct.float() / total)

  losses.append(total_loss)
  accuracies.append(correct.float() / total)
  print("Train Loss:", total_loss, "Accuracy:", correct.float() / total)
# Out:
#   0%|          | 0/9137 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2418: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Batch Loss: 69.25467556715012 Accuracy: tensor(0.5250, device='cuda:0')
# Batch Loss: 138.31639498472214 Accuracy: tensor(0.5219, device='cuda:0')
# Batch Loss: 207.08487117290497 Accuracy: tensor(0.5321, device='cuda:0')
# Batch Loss: 275.1113106608391 Accuracy: tensor(0.5445, device='cuda:0')
# Batch Loss: 341.3435778617859 Accuracy: tensor(0.5592, device='cuda:0')
# Batch Loss: 404.26704224944115 Accuracy: tensor(0.5750, device='cuda:0')
# Batch Loss: 466.4220041036606 Accuracy: tensor(0.5875, device='cuda:0')
# Batch Loss: 528.1753177046776 Accuracy: tensor(0.5974, device='cuda:0')
# Batch Loss: 587.5966936945915 Accuracy: tensor(0.6072, device='cuda:0')
# Batch Loss: 646.5270308852196 Accuracy: tensor(0.6157, device='cuda:0')
# Batch Loss: 703.8973246514797 Accuracy: tensor(0.6241, device='cuda:0')
# Batch Loss: 762.0893881618977 Accuracy: tensor(0.6294, device='cuda:0')
# Batch Loss: 818.7401643097401 Accuracy: tensor(0.6360, device='cuda:0')
# Batch Loss: 876.427414149046 Accuracy: tensor(0.6409, device='cuda:0')
# Batch Loss: 933.669487208128 Accuracy: tensor(0.6452, device='cuda:0')
# Batch Loss: 988.644214630127 Accuracy: tensor(0.6498, device='cuda:0')
# Batch Loss: 1042.9494782686234 Accuracy: tensor(0.6542, device='cuda:0')
# Batch Loss: 1096.7901439070702 Accuracy: tensor(0.6584, device='cuda:0')
# Batch Loss: 1150.095326423645 Accuracy: tensor(0.6620, device='cuda:0')
# Batch Loss: 1201.9656132161617 Accuracy: tensor(0.6662, device='cuda:0')
# Batch Loss: 1254.3961871266365 Accuracy: tensor(0.6696, device='cuda:0')
# Batch Loss: 1307.0276857316494 Accuracy: tensor(0.6725, device='cuda:0')
# Batch Loss: 1359.4273139238358 Accuracy: tensor(0.6754, device='cuda:0')
# Batch Loss: 1411.7375562787056 Accuracy: tensor(0.6783, device='cuda:0')
# Batch Loss: 1462.318158596754 Accuracy: tensor(0.6813, device='cuda:0')
# Batch Loss: 1512.4684262126684 Accuracy: tensor(0.6839, device='cuda:0')
# Batch Loss: 1565.067189142108 Accuracy: tensor(0.6865, device='cuda:0')
# Batch Loss: 1615.2412192970514 Accuracy: tensor(0.6889, device='cuda:0')
# Batch Loss: 1667.5953406244516 Accuracy: tensor(0.6905, device='cuda:0')
# Batch Loss: 1719.6290543824434 Accuracy: tensor(0.6920, device='cuda:0')
# Batch Loss: 1769.5133723318577 Accuracy: tensor(0.6939, device='cuda:0')
# Batch Loss: 1820.9545106589794 Accuracy: tensor(0.6958, device='cuda:0')
# Batch Loss: 1870.4631322920322 Accuracy: tensor(0.6977, device='cuda:0')
# Batch Loss: 1919.6917809396982 Accuracy: tensor(0.6995, device='cuda:0')
# Batch Loss: 1968.958760946989 Accuracy: tensor(0.7015, device='cuda:0')
# Batch Loss: 2016.497147038579 Accuracy: tensor(0.7034, device='cuda:0')
# Batch Loss: 2063.687491238117 Accuracy: tensor(0.7053, device='cuda:0')
# Batch Loss: 2110.087843567133 Accuracy: tensor(0.7073, device='cuda:0')
# Batch Loss: 2157.1024408489466 Accuracy: tensor(0.7088, device='cuda:0')
# Batch Loss: 2203.4274507910013 Accuracy: tensor(0.7105, device='cuda:0')
# Batch Loss: 2250.0221842080355 Accuracy: tensor(0.7123, device='cuda:0')
# Batch Loss: 2297.058695167303 Accuracy: tensor(0.7135, device='cuda:0')
# Batch Loss: 2346.0525537729263 Accuracy: tensor(0.7149, device='cuda:0')
# Batch Loss: 2392.3648858219385 Accuracy: tensor(0.7162, device='cuda:0')
# Batch Loss: 2436.274671062827 Accuracy: tensor(0.7176, device='cuda:0')
# Batch Loss: 2483.2579415142536 Accuracy: tensor(0.7189, device='cuda:0')
# Batch Loss: 2531.0519151836634 Accuracy: tensor(0.7201, device='cuda:0')
# Batch Loss: 2575.924948140979 Accuracy: tensor(0.7217, device='cuda:0')
# Batch Loss: 2622.8516091406345 Accuracy: tensor(0.7228, device='cuda:0')
# Batch Loss: 2667.8481713086367 Accuracy: tensor(0.7239, device='cuda:0')
# Batch Loss: 2712.409034729004 Accuracy: tensor(0.7250, device='cuda:0')
# Batch Loss: 2757.1545292288065 Accuracy: tensor(0.7261, device='cuda:0')
# Batch Loss: 2803.2177730947733 Accuracy: tensor(0.7272, device='cuda:0')
# Batch Loss: 2847.9649830013514 Accuracy: tensor(0.7283, device='cuda:0')
# Batch Loss: 2893.847650885582 Accuracy: tensor(0.7292, device='cuda:0')
# Batch Loss: 2938.7363255620003 Accuracy: tensor(0.7304, device='cuda:0')
# Batch Loss: 2980.9651368260384 Accuracy: tensor(0.7318, device='cuda:0')
# Batch Loss: 3025.0287811607122 Accuracy: tensor(0.7329, device='cuda:0')
# Batch Loss: 3071.0019100755453 Accuracy: tensor(0.7337, device='cuda:0')
# Batch Loss: 3113.7681467086077 Accuracy: tensor(0.7347, device='cuda:0')
# Batch Loss: 3157.5583598166704 Accuracy: tensor(0.7356, device='cuda:0')
# Batch Loss: 3199.3109754770994 Accuracy: tensor(0.7366, device='cuda:0')
# Batch Loss: 3244.154568016529 Accuracy: tensor(0.7372, device='cuda:0')
# Batch Loss: 3288.890360429883 Accuracy: tensor(0.7380, device='cuda:0')
# Batch Loss: 3332.005037114024 Accuracy: tensor(0.7389, device='cuda:0')
# Batch Loss: 3375.8689813911915 Accuracy: tensor(0.7398, device='cuda:0')
# Batch Loss: 3420.7448659837246 Accuracy: tensor(0.7403, device='cuda:0')
# Batch Loss: 3462.8937004357576 Accuracy: tensor(0.7413, device='cuda:0')
# Batch Loss: 3504.8419790267944 Accuracy: tensor(0.7422, device='cuda:0')
# Batch Loss: 3548.033026486635 Accuracy: tensor(0.7428, device='cuda:0')
# Batch Loss: 3590.5502100139856 Accuracy: tensor(0.7437, device='cuda:0')
# Batch Loss: 3634.9597095251083 Accuracy: tensor(0.7444, device='cuda:0')
# Batch Loss: 3680.708195120096 Accuracy: tensor(0.7450, device='cuda:0')
# Batch Loss: 3722.038083985448 Accuracy: tensor(0.7457, device='cuda:0')
# Batch Loss: 3764.0736028701067 Accuracy: tensor(0.7465, device='cuda:0')
# Batch Loss: 3805.264397278428 Accuracy: tensor(0.7473, device='cuda:0')
# Batch Loss: 3848.106125995517 Accuracy: tensor(0.7480, device='cuda:0')
# Batch Loss: 3889.9581340402365 Accuracy: tensor(0.7488, device='cuda:0')
# Batch Loss: 3933.9286901056767 Accuracy: tensor(0.7494, device='cuda:0')
# Batch Loss: 3976.702324002981 Accuracy: tensor(0.7498, device='cuda:0')
# Batch Loss: 4019.2397758215666 Accuracy: tensor(0.7505, device='cuda:0')
# Batch Loss: 4058.744428962469 Accuracy: tensor(0.7512, device='cuda:0')
# Batch Loss: 4101.055471375585 Accuracy: tensor(0.7518, device='cuda:0')
# Batch Loss: 4141.13045053184 Accuracy: tensor(0.7525, device='cuda:0')
# Batch Loss: 4182.203438416123 Accuracy: tensor(0.7531, device='cuda:0')
# Batch Loss: 4223.661754123867 Accuracy: tensor(0.7538, device='cuda:0')
# Batch Loss: 4264.264029569924 Accuracy: tensor(0.7544, device='cuda:0')
# Batch Loss: 4306.641763858497 Accuracy: tensor(0.7550, device='cuda:0')
# Batch Loss: 4347.752471648157 Accuracy: tensor(0.7556, device='cuda:0')
# Batch Loss: 4390.9227459952235 Accuracy: tensor(0.7561, device='cuda:0')
# Batch Loss: 4436.6430522874 Accuracy: tensor(0.7565, device='cuda:0')
# Train Loss: 4451.998799197376 Accuracy: tensor(0.7567, device='cuda:0')
#   0%|          | 0/9137 [00:00<?, ?it/s]
# Batch Loss: 39.255688942968845 Accuracy: tensor(0.8219, device='cuda:0')
# Batch Loss: 78.93941567093134 Accuracy: tensor(0.8184, device='cuda:0')
# Batch Loss: 117.5753080919385 Accuracy: tensor(0.8200, device='cuda:0')
# Batch Loss: 156.05260226875544 Accuracy: tensor(0.8223, device='cuda:0')
# Batch Loss: 194.9609649553895 Accuracy: tensor(0.8241, device='cuda:0')
# Batch Loss: 233.8115511611104 Accuracy: tensor(0.8229, device='cuda:0')
# Batch Loss: 273.13768834620714 Accuracy: tensor(0.8220, device='cuda:0')
# Batch Loss: 312.80857663601637 Accuracy: tensor(0.8218, device='cuda:0')
# Batch Loss: 351.176371358335 Accuracy: tensor(0.8228, device='cuda:0')
# Batch Loss: 388.92075615376234 Accuracy: tensor(0.8243, device='cuda:0')
# Batch Loss: 431.89827797561884 Accuracy: tensor(0.8219, device='cuda:0')
# Batch Loss: 472.76609898358583 Accuracy: tensor(0.8209, device='cuda:0')
# Batch Loss: 510.9513918235898 Accuracy: tensor(0.8207, device='cuda:0')
# Batch Loss: 552.2571426555514 Accuracy: tensor(0.8196, device='cuda:0')
# Batch Loss: 588.9482426568866 Accuracy: tensor(0.8202, device='cuda:0')
# Batch Loss: 629.4935433492064 Accuracy: tensor(0.8195, device='cuda:0')
# Batch Loss: 666.9724967703223 Accuracy: tensor(0.8199, device='cuda:0')
# Batch Loss: 705.4404566958547 Accuracy: tensor(0.8202, device='cuda:0')
# Batch Loss: 745.3042273893952 Accuracy: tensor(0.8202, device='cuda:0')
# Batch Loss: 783.2983136698604 Accuracy: tensor(0.8208, device='cuda:0')
# Batch Loss: 821.6514395549893 Accuracy: tensor(0.8211, device='cuda:0')
# Batch Loss: 859.7437429726124 Accuracy: tensor(0.8211, device='cuda:0')
# Batch Loss: 897.6454733908176 Accuracy: tensor(0.8214, device='cuda:0')
# Batch Loss: 935.5299372971058 Accuracy: tensor(0.8216, device='cuda:0')
# Batch Loss: 973.5412057191133 Accuracy: tensor(0.8218, device='cuda:0')
# Batch Loss: 1010.7156235203147 Accuracy: tensor(0.8218, device='cuda:0')
# Batch Loss: 1047.6427744477987 Accuracy: tensor(0.8222, device='cuda:0')
# Batch Loss: 1085.015531271696 Accuracy: tensor(0.8227, device='cuda:0')
# Batch Loss: 1122.115184277296 Accuracy: tensor(0.8225, device='cuda:0')
# Batch Loss: 1161.7083854079247 Accuracy: tensor(0.8223, device='cuda:0')
# Batch Loss: 1196.7955228164792 Accuracy: tensor(0.8229, device='cuda:0')
# Batch Loss: 1235.3989469632506 Accuracy: tensor(0.8229, device='cuda:0')
# Batch Loss: 1272.983483158052 Accuracy: tensor(0.8230, device='cuda:0')
# Batch Loss: 1312.3807262703776 Accuracy: tensor(0.8226, device='cuda:0')
# Batch Loss: 1351.0492406114936 Accuracy: tensor(0.8227, device='cuda:0')
# Batch Loss: 1387.020446702838 Accuracy: tensor(0.8229, device='cuda:0')
# Batch Loss: 1424.6607766449451 Accuracy: tensor(0.8230, device='cuda:0')
# Batch Loss: 1462.8132108449936 Accuracy: tensor(0.8232, device='cuda:0')
# Batch Loss: 1500.5682331696153 Accuracy: tensor(0.8233, device='cuda:0')
# Batch Loss: 1538.9941700175405 Accuracy: tensor(0.8233, device='cuda:0')
# Batch Loss: 1576.9764864370227 Accuracy: tensor(0.8235, device='cuda:0')
# Batch Loss: 1616.710998468101 Accuracy: tensor(0.8234, device='cuda:0')
# Batch Loss: 1651.0109109729528 Accuracy: tensor(0.8239, device='cuda:0')
# Batch Loss: 1689.00737413764 Accuracy: tensor(0.8240, device='cuda:0')
# Batch Loss: 1727.463648185134 Accuracy: tensor(0.8240, device='cuda:0')
# Batch Loss: 1765.7002367824316 Accuracy: tensor(0.8239, device='cuda:0')
# Batch Loss: 1801.2495795190334 Accuracy: tensor(0.8242, device='cuda:0')
# Batch Loss: 1839.93837608397 Accuracy: tensor(0.8241, device='cuda:0')
# Batch Loss: 1876.6235082894564 Accuracy: tensor(0.8245, device='cuda:0')
# Batch Loss: 1913.9377206414938 Accuracy: tensor(0.8245, device='cuda:0')
# Batch Loss: 1951.394357278943 Accuracy: tensor(0.8247, device='cuda:0')
# Batch Loss: 1990.137919679284 Accuracy: tensor(0.8247, device='cuda:0')
# Batch Loss: 2028.527517594397 Accuracy: tensor(0.8244, device='cuda:0')
# Batch Loss: 2066.3079792559147 Accuracy: tensor(0.8243, device='cuda:0')
# Batch Loss: 2105.6944659352303 Accuracy: tensor(0.8242, device='cuda:0')
# Batch Loss: 2141.020334981382 Accuracy: tensor(0.8245, device='cuda:0')
# Batch Loss: 2175.44506406039 Accuracy: tensor(0.8250, device='cuda:0')
# Batch Loss: 2211.9260587096214 Accuracy: tensor(0.8252, device='cuda:0')
# Batch Loss: 2249.8247160613537 Accuracy: tensor(0.8252, device='cuda:0')
# Batch Loss: 2290.287687972188 Accuracy: tensor(0.8250, device='cuda:0')
# Batch Loss: 2327.5242549031973 Accuracy: tensor(0.8251, device='cuda:0')
# Batch Loss: 2366.3792987316847 Accuracy: tensor(0.8249, device='cuda:0')
# Batch Loss: 2401.353662893176 Accuracy: tensor(0.8252, device='cuda:0')
# Batch Loss: 2439.2636911198497 Accuracy: tensor(0.8254, device='cuda:0')
# Batch Loss: 2475.906424894929 Accuracy: tensor(0.8254, device='cuda:0')
# Batch Loss: 2512.7188106775284 Accuracy: tensor(0.8256, device='cuda:0')
# Batch Loss: 2550.7503399699926 Accuracy: tensor(0.8255, device='cuda:0')
# Batch Loss: 2588.1119681745768 Accuracy: tensor(0.8256, device='cuda:0')
# Batch Loss: 2624.7768649086356 Accuracy: tensor(0.8259, device='cuda:0')
# Batch Loss: 2660.7571287602186 Accuracy: tensor(0.8259, device='cuda:0')
# Batch Loss: 2697.9475283250213 Accuracy: tensor(0.8260, device='cuda:0')
# Batch Loss: 2734.1518992483616 Accuracy: tensor(0.8263, device='cuda:0')
# Batch Loss: 2769.953475728631 Accuracy: tensor(0.8265, device='cuda:0')
# Batch Loss: 2806.0080553740263 Accuracy: tensor(0.8266, device='cuda:0')
# Batch Loss: 2842.0810826197267 Accuracy: tensor(0.8266, device='cuda:0')
# Batch Loss: 2878.1943298727274 Accuracy: tensor(0.8267, device='cuda:0')
# Batch Loss: 2915.8495313078165 Accuracy: tensor(0.8269, device='cuda:0')
# Batch Loss: 2954.490028642118 Accuracy: tensor(0.8269, device='cuda:0')
# Batch Loss: 2989.9834941849113 Accuracy: tensor(0.8271, device='cuda:0')
# Batch Loss: 3025.5518536791205 Accuracy: tensor(0.8272, device='cuda:0')
# Batch Loss: 3061.819125212729 Accuracy: tensor(0.8272, device='cuda:0')
# Batch Loss: 3098.441673144698 Accuracy: tensor(0.8272, device='cuda:0')
# Batch Loss: 3135.7052254527807 Accuracy: tensor(0.8272, device='cuda:0')
# Batch Loss: 3169.066666059196 Accuracy: tensor(0.8276, device='cuda:0')
# Batch Loss: 3203.7874259352684 Accuracy: tensor(0.8277, device='cuda:0')
# Batch Loss: 3239.6942571923137 Accuracy: tensor(0.8278, device='cuda:0')
# Batch Loss: 3275.833267711103 Accuracy: tensor(0.8281, device='cuda:0')
# Batch Loss: 3311.2695502862334 Accuracy: tensor(0.8282, device='cuda:0')
# Batch Loss: 3344.817383632064 Accuracy: tensor(0.8284, device='cuda:0')
# Batch Loss: 3380.4766165539622 Accuracy: tensor(0.8286, device='cuda:0')
# Batch Loss: 3416.009571544826 Accuracy: tensor(0.8287, device='cuda:0')
# Train Loss: 3429.252386085689 Accuracy: tensor(0.8287, device='cuda:0')
#   0%|          | 0/9137 [00:00<?, ?it/s]
# Batch Loss: 34.192659467458725 Accuracy: tensor(0.8500, device='cuda:0')
# Batch Loss: 69.10339975357056 Accuracy: tensor(0.8487, device='cuda:0')
# Batch Loss: 101.56368239969015 Accuracy: tensor(0.8502, device='cuda:0')
# Batch Loss: 135.34768897294998 Accuracy: tensor(0.8489, device='cuda:0')
# Batch Loss: 168.38832645118237 Accuracy: tensor(0.8496, device='cuda:0')
# Batch Loss: 201.33621939271688 Accuracy: tensor(0.8507, device='cuda:0')
# Batch Loss: 234.0136626958847 Accuracy: tensor(0.8514, device='cuda:0')
# Batch Loss: 268.0524907410145 Accuracy: tensor(0.8513, device='cuda:0')
# Batch Loss: 303.6666154488921 Accuracy: tensor(0.8504, device='cuda:0')
# Batch Loss: 338.3616046383977 Accuracy: tensor(0.8496, device='cuda:0')
# Batch Loss: 370.6627522855997 Accuracy: tensor(0.8500, device='cuda:0')
# Batch Loss: 406.1983975470066 Accuracy: tensor(0.8491, device='cuda:0')
# Batch Loss: 438.9228173866868 Accuracy: tensor(0.8492, device='cuda:0')
# Batch Loss: 472.594027929008 Accuracy: tensor(0.8496, device='cuda:0')
# Batch Loss: 505.52295115590096 Accuracy: tensor(0.8497, device='cuda:0')
# Batch Loss: 538.319898493588 Accuracy: tensor(0.8505, device='cuda:0')
# Batch Loss: 570.71840172261 Accuracy: tensor(0.8506, device='cuda:0')
# Batch Loss: 600.758496068418 Accuracy: tensor(0.8510, device='cuda:0')
# Batch Loss: 634.6398232653737 Accuracy: tensor(0.8504, device='cuda:0')
# Batch Loss: 667.8260434120893 Accuracy: tensor(0.8506, device='cuda:0')
# Batch Loss: 701.0423145964742 Accuracy: tensor(0.8509, device='cuda:0')
# Batch Loss: 734.3799867257476 Accuracy: tensor(0.8509, device='cuda:0')
# Batch Loss: 767.2860635071993 Accuracy: tensor(0.8509, device='cuda:0')
# Batch Loss: 802.2550440132618 Accuracy: tensor(0.8511, device='cuda:0')
# Batch Loss: 836.6583344265819 Accuracy: tensor(0.8509, device='cuda:0')
# Batch Loss: 869.3508766517043 Accuracy: tensor(0.8510, device='cuda:0')
# Batch Loss: 900.7146552205086 Accuracy: tensor(0.8517, device='cuda:0')
# Batch Loss: 932.5821637958288 Accuracy: tensor(0.8520, device='cuda:0')
# Batch Loss: 967.4770440608263 Accuracy: tensor(0.8517, device='cuda:0')
# Batch Loss: 999.9482035636902 Accuracy: tensor(0.8520, device='cuda:0')
# Batch Loss: 1030.8745111562312 Accuracy: tensor(0.8524, device='cuda:0')
# Batch Loss: 1063.5703222118318 Accuracy: tensor(0.8526, device='cuda:0')
# Batch Loss: 1097.224322590977 Accuracy: tensor(0.8523, device='cuda:0')
# Batch Loss: 1131.6223355866969 Accuracy: tensor(0.8520, device='cuda:0')
# Batch Loss: 1162.9385672174394 Accuracy: tensor(0.8523, device='cuda:0')
# Batch Loss: 1195.277484100312 Accuracy: tensor(0.8526, device='cuda:0')
# Batch Loss: 1227.3959377743304 Accuracy: tensor(0.8528, device='cuda:0')
# Batch Loss: 1260.370101686567 Accuracy: tensor(0.8530, device='cuda:0')
# Batch Loss: 1293.151893030852 Accuracy: tensor(0.8531, device='cuda:0')
# Batch Loss: 1326.643945362419 Accuracy: tensor(0.8530, device='cuda:0')
# Batch Loss: 1358.8945856802166 Accuracy: tensor(0.8532, device='cuda:0')
# Batch Loss: 1392.626858022064 Accuracy: tensor(0.8530, device='cuda:0')
# Batch Loss: 1428.3938972242177 Accuracy: tensor(0.8527, device='cuda:0')
# Batch Loss: 1460.8408534936607 Accuracy: tensor(0.8529, device='cuda:0')
# Batch Loss: 1495.3298368863761 Accuracy: tensor(0.8529, device='cuda:0')
# Batch Loss: 1526.1529224328697 Accuracy: tensor(0.8531, device='cuda:0')
# Batch Loss: 1555.5344858020544 Accuracy: tensor(0.8535, device='cuda:0')
# Batch Loss: 1588.635533131659 Accuracy: tensor(0.8535, device='cuda:0')
# Batch Loss: 1623.1766128242016 Accuracy: tensor(0.8534, device='cuda:0')
# Batch Loss: 1655.8151953443885 Accuracy: tensor(0.8535, device='cuda:0')
# Batch Loss: 1688.151779986918 Accuracy: tensor(0.8535, device='cuda:0')
# Batch Loss: 1723.0713544636965 Accuracy: tensor(0.8535, device='cuda:0')
# Batch Loss: 1758.1681522876024 Accuracy: tensor(0.8533, device='cuda:0')
# Batch Loss: 1793.059433966875 Accuracy: tensor(0.8531, device='cuda:0')
# Batch Loss: 1826.3487560972571 Accuracy: tensor(0.8530, device='cuda:0')
# Batch Loss: 1860.8108740374446 Accuracy: tensor(0.8529, device='cuda:0')
# Batch Loss: 1891.9043481945992 Accuracy: tensor(0.8531, device='cuda:0')
# Batch Loss: 1927.362865947187 Accuracy: tensor(0.8530, device='cuda:0')
# Batch Loss: 1959.4421796873212 Accuracy: tensor(0.8531, device='cuda:0')
# Batch Loss: 1993.6949020177126 Accuracy: tensor(0.8529, device='cuda:0')
# Batch Loss: 2023.5729032307863 Accuracy: tensor(0.8532, device='cuda:0')
# Batch Loss: 2054.778244294226 Accuracy: tensor(0.8534, device='cuda:0')
# Batch Loss: 2085.9147337153554 Accuracy: tensor(0.8535, device='cuda:0')
# Batch Loss: 2119.7316823378205 Accuracy: tensor(0.8537, device='cuda:0')
# Batch Loss: 2151.2717766463757 Accuracy: tensor(0.8538, device='cuda:0')
# Batch Loss: 2182.463243227452 Accuracy: tensor(0.8540, device='cuda:0')
# Batch Loss: 2216.284560162574 Accuracy: tensor(0.8539, device='cuda:0')
# Batch Loss: 2249.4752258323133 Accuracy: tensor(0.8539, device='cuda:0')
# Batch Loss: 2284.1140951551497 Accuracy: tensor(0.8536, device='cuda:0')

# %%
losses, accuracies

# %% [markdown]
# 테스트 데이터셋 정확도 확인하기

# %%
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
  y_batch = y_batch.to(device)
  y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
  _, predicted = torch.max(y_pred, 1)
  test_correct += (predicted == y_batch).sum()
  test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)

# %%
# 모델 저장하기
torch.save(model.state_dict(), "model.pt")
